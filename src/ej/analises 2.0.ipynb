# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ej_comments_all = pd.read_json('/tmp/airflow/comments_only.json')

# %%
ej_comments = pd.DataFrame(data=ej_comments_all, columns=['comentário_id', 'comentário', 'concorda', 'discorda', 'pulados'])
ej_comments['concorda'] = ej_comments['concorda'].map(lambda x: x * 100)
ej_comments['discorda'] = ej_comments['discorda'].map(lambda x: x * 100)
ej_comments['pulados'] = ej_comments['pulados'].map(lambda x: x * 100)
ej_comments['compilado'] = ''
for index,value in enumerate(ej_comments['concorda']):
    ej_comments['compilado'][index] = [ej_comments['concorda'][index], ej_comments['discorda'][index], ej_comments['pulados'][index]]
ej_comments
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#     comentário_id                                         comentário  \
# 0             666  Caixa 2 tem que ser crime sim! Se não punir os...
# 1             667  Tornar o Caixa 2 crime ajudará a evitar essa p...
# 2             668  O Caixa 2 é crime e muda o resultado das eleiç...
# 3             669  Acho que a Lei de Abuso de Autoridade é uma mo...
# 4             670  É preciso muito cuidado com a Lei de Abuso de ...
# 5             671  Ninguém pode ficar acima da Lei! Por isso, é p...
# 6             672  Cadeia por muito tempo e obrigação de devolver...
# 7             673  Aumentar a pena para casos de corrupção e exig...
# 8             674  Só poderemos endurecer as penas em casos de co...
# 9             727  É fundamental que se crie dispositivos para au...
# 10            728  Não tenho conhecimento da lei,mas acredito que...
# 11            729  O essencial é tornar caixa 2 crime com severa ...
# 12            730  A corrupção é uma doença que não tem cura,os p...
# 13            731  Tais pessoas devem ter um limite, pois o fruto...
# 14            732  Precisamos de sistemas de transparência e de f...
# 15            733  Infelizmente, o legislativo já garantiu legali...
# 16            737  A autonomia da Polícia Federal é importante pa...
# 17            738  Não precisa esperar pra endurecer as penas. De...
# 18            739  Acredito sim na cura, o caminho é transparênci...
# 19            740  Essa questão já apareceu. Acredito SIM que a c...
# 20            742  É preciso aplicar leis e punições severas. Se ...
# 21            743  O compliance corporativo é fundamental para a ...
# 22            744  A corrupção, em si mesma, não tem cura. No ent...
# 23            745  É necessário ações que coibam o desvio do dinh...
# 24            749  O político preso tem que pagar por suas despes...
# 25            751  O stf deveria ser composto por juizes indicado...
# 26            754  Penso que o controle já que ocorrer em qualque...
# 27            755  Acho que os juízes precisam ser imparciais, es...
# 28            756  Criar estratégias de conscientização da popula...
# 29            760  Eu acho muito recente para opinar espero do ou...
# 30            761  Especialmente os membros do STF que soltam os ...
# 31            762  Com a saída de Sérgio Moro do governo e o enfr...
# 32            764  A transparência na gestão pública é exigência ...
# 33            765  A sociedade deve estar sempre alerta e mobiliz...
#
#       concorda    discorda    pulados  \
# 0    92.982456    4.385965   2.631579
# 1    92.792793    3.603604   3.603604
# 2    94.594595    3.603604   1.801802
# 3    76.785714   19.642857   3.571429
# 4    91.304348    5.217391   3.478261
# 5    85.087719   11.403509   3.508772
# 6    87.603306    4.958678   7.438017
# 7    85.000000   12.500000   2.500000
# 8    64.545455   31.818182   3.636364
# 9    97.000000    1.000000   2.000000
# 10   66.000000   22.000000  12.000000
# 11   91.000000    5.000000   4.000000
# 12   86.842105   11.842105   1.315789
# 13   79.746835   10.126582  10.126582
# 14   97.402597    2.597403   0.000000
# 15   46.250000   40.000000  13.750000
# 16   95.121951    4.878049   0.000000
# 17   84.444444    8.888889   6.666667
# 18   91.111111    4.444444   4.444444
# 19   90.909091    4.545455   4.545455
# 20   90.000000    7.500000   2.500000
# 21   84.210526    2.631579  13.157895
# 22   88.095238   11.904762   0.000000
# 23  100.000000    0.000000   0.000000
# 24   75.000000    8.333333  16.666667
# 25   90.909091    0.000000   9.090909
# 26   43.750000   25.000000  31.250000
# 27   50.000000   30.000000  20.000000
# 28   63.636364   27.272727   9.090909
# 29   36.363636   36.363636  27.272727
# 30   88.888889   11.111111   0.000000
# 31   66.666667   22.222222  11.111111
# 32    0.000000  100.000000   0.000000
# 33  100.000000    0.000000   0.000000
#
#                                             compilado
# 0               [92.98245614, 4.38596491, 2.63157895]
# 1           [92.79279279000001, 3.6036036, 3.6036036]
# 2                 [94.59459459, 3.6036036, 1.8018018]
# 3              [76.78571429, 19.64285714, 3.57142857]
# 4                [91.30434783, 5.2173913, 3.47826087]
# 5               [85.0877193, 11.40350877, 3.50877193]
# 6   [87.60330579000001, 4.95867769, 7.438016530000...
# 7                                   [85.0, 12.5, 2.5]
# 8   [64.54545455, 31.818181820000003, 3.6363636400...
# 9                                    [97.0, 1.0, 2.0]
# 10                                 [66.0, 22.0, 12.0]
# 11                                   [91.0, 5.0, 4.0]
# 12     [86.84210526, 11.84210526, 1.3157894700000001]
# 13  [79.74683544000001, 10.126582280000001, 10.126...
# 14                       [97.4025974, 2.5974026, 0.0]
# 15                  [46.25, 40.0, 13.750000000000002]
# 16                     [95.12195122, 4.87804878, 0.0]
# 17       [84.44444444, 8.88888889, 6.666666670000001]
# 18  [91.11111111, 4.444444440000001, 4.44444444000...
# 19              [90.90909091, 4.54545455, 4.54545455]
# 20                                   [90.0, 7.5, 2.5]
# 21      [84.21052632, 2.63157895, 13.157894740000001]
# 22                      [88.0952381, 11.9047619, 0.0]
# 23                                  [100.0, 0.0, 0.0]
# 24             [75.0, 8.33333333, 16.666666669999998]
# 25                     [90.90909091, 0.0, 9.09090909]
# 26                               [43.75, 25.0, 31.25]
# 27                   [50.0, 30.000000000000004, 20.0]
# 28      [63.636363640000006, 27.27272727, 9.09090909]
# 29            [36.36363636, 36.36363636, 27.27272727]
# 30             [88.88888889, 11.111111110000001, 0.0]
# 31  [66.66666667000001, 22.222222220000003, 11.111...
# 32                                  [0.0, 100.0, 0.0]
# 33                                  [100.0, 0.0, 0.0]
